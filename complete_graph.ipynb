# %%
import pandas as pd
import os

# %%
folder_dir = 'C:/Users/kirtan/Documents/AI/class_city_dataset/Heuristic_function_of_cities'

# %%
merged_data = pd.DataFrame()

# %%
for file in os.listdir(folder_dir):
    df = pd.read_csv('C:/Users/kirtan/Documents/AI/class_city_dataset/Heuristic_function_of_cities/' + file)
    merged_data = merged_data.append(df, ignore_index=True)

merged_data.to_csv('C:/Users/kirtan/Desktop/merged.csv', index=True)
# Out:
# C:\Users\kirtan\AppData\Local\Temp\ipykernel_6576\2454384589.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(df, ignore_index=True)
# C:\Users\kirtan\AppData\Local\Temp\ipykernel_6576\2454384589.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(df, ignore_index=True)
# C:\Users\kirtan\AppData\Local\Temp\ipykernel_6576\2454384589.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(df, ignore_index=True)
# C:\Users\kirtan\AppData\Local\Temp\ipykernel_6576\2454384589.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
for i, j in df.items():
    print(i, j)
# Out:
# node1 0     Una
# 1     Una
# 2     Una
# 3     Una
# 4     Una
# 5     Una
# 6     Una
# 7     Una
# 8     Una
# 9     Una
# 10    Una
# 11    Una
# 12    Una
# 13    Una
# 14    Una
# 15    Una
# 16    Una
# 17    Una
# 18    Una
# 19    Una
# 20    Una
# 21    Una
# 22    Una
# 23    Una
# 24    Una
# 25    Una
# 26    Una
# 27    Una
# 28    Una
# 29    Una
# 30    Una
# 31    Una
# 32    Una
# 33    Una
# 34    Una
# 35    Una
# 36    Una
# 37    Una
# 38    Una
# 39    Una
# 40    Una
# 41    Una
# 42    Una
# 43    Una
# 44    Una
# 45    Una
# Name: node1, dtype: object
# node2 0            Lucknow
# 1          Rajsamand
# 2          Raebareli
# 3              Patna
# 4               Gaya
# 5               Kota
# 6              Sikar
# 7          Prayagraj
# 8             Bhopal
# 9                Una
# 10             Bundi
# 11         Sarangarh
# 12         Lakhimpur
# 13         Madhepura
# 14             Arrah
# 15         Daudnagar
# 16          Belagavi
# ...
